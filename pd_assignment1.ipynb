# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#                                               ANSWER 1 
import pandas as pd 
list = [4, 8, 15, 16, 23,42]
series = pd.Series(list)
print(series)
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %%
#                                                ANSWER 2 
import pandas as pd 
student_name = ['MANISHA NARESH' , 'KUMAR' , 'BIMLESH KUMAR SINGH' , 'SHAMBHU' , 'NARAIN SINGH' , 'DHARAMBIR SINGH' , 'JAGDISH YADAV' , 'RAGNI KUMARI' , 'BIMLESH ROY' , 'VANDANA SINGH' , 'HARENDER PRATAP SINGH']
series = pd.Series(student_name)
print(series)
# Out:
# 0            MANISHA NARESH
# 1                     KUMAR
# 2       BIMLESH KUMAR SINGH
# 3                   SHAMBHU
# 4              NARAIN SINGH
# 5           DHARAMBIR SINGH
# 6             JAGDISH YADAV
# 7              RAGNI KUMARI
# 8               BIMLESH ROY
# 9             VANDANA SINGH
# 10    HARENDER PRATAP SINGH
# dtype: object

# %%
#                                                   ANSWER 3
import pandas as pd 
data = [['Alice',25,'Female'],['Bob',30,'Male'],['Claire',27,'Female']]
df = pd.DataFrame(data, columns=['Name', 'Age','Gender'])
df
# Out:
#      Name  Age  Gender
# 0   Alice   25  Female
# 1     Bob   30    Male
# 2  Claire   27  Female

# %%
#                          ANSWER 4 
#A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.
#Pandas Series : 
# 1 One-dimensional 
# 2 Homogenous-Series elements must be of the same data type
# 3 Size-immutable – Once created, the size of a Series object cannot be changed


print("example of Pandas Series")
import pandas as pd 
list = {1 : 'mon', 2 : 'tue', 3 : 'wed', 4 : 'thu', 5 : 'fri' , 6 : 'sat', 7 : 'sun'}
series = pd.Series(list)
print(series)
print("")

# Pandas DataFrame : 
# 1 Two-dimensional
# 2 Heterogenous – DataFrame elements can have different data types
# 3 Size-mutable – Elements can be dropped or added in an existing DataFrame


print("example of Pandas DataFrame")
import pandas as pd 
data = [[1,'mon'],[2,'tue'],[3 ,'wed'],[4,'thu'],[5,'fri'],[6,'sat'],[7,'sun']]
df = pd.DataFrame(data,columns=['S.no', 'Days'])
df
# Out:
# example of Pandas Series
# 1    mon
# 2    tue
# 3    wed
# 4    thu
# 5    fri
# 6    sat
# 7    sun
# dtype: object
#
# example of Pandas DataFrame
#    S.no Days
# 0     1  mon
# 1     2  tue
# 2     3  wed
# 3     4  thu
# 4     5  fri
# 5     6  sat
# 6     7  sun

# %%
#                                           ANSWER 5 
# Read Data , Describe ,fillna , dropna , drop etc are some common functions you can use to manipulate data in a Pandas DataFrame

# %%
#                                          ANSWER 5 CONTINUE (READ DATA)
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
#                                          ANSWER 5 CONTINUE (DESCRIBE)
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#                                           ANSWER 5 CONTINUE (fillana)
df.fillna("Nodatapresent")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex            Age  \
# 0                              Braund, Mr. Owen Harris    male           22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female           38.0
# 2                               Heikkinen, Miss. Laina  female           26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           35.0
# 4                             Allen, Mr. William Henry    male           35.0
# ...

# %%
#                                           ANSWER 5 CONTINUE (dropna)
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#                                            ANSWER 5 CONTINUE (DROP) 
df.drop('PassengerId',axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
#                                                  ANSWER 6 
# DataFrame is mutable in nature.

# %%
#                                                 ANSWER 7
#By using concat() method you can merge multiple series together into DataFrame.
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df1 =pd.read_csv('taxonomy.csv.xls')
df2 = df[['Name','Sex','Age']][1:10]
df3 = df1[['taxonomy_id','name','parent_id']][1:10]
pd.concat([df2,df3])
# Out:
#                                                 Name     Sex   Age  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 1                                                NaN     NaN   NaN
# 2                                                NaN     NaN   NaN
# 3                                                NaN     NaN   NaN
# 4                                                NaN     NaN   NaN
# ...
